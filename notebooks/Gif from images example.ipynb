# %%
import sys
sys.path.append('../')
# hack for correct import

# %%
from skimage.data import coffee
from utils.giffy import Giffy
from skimage.util import invert
# %matplotlib inline

# %%
cof=coffee()
inv=invert(coffee())

# %%
g = Giffy(np_images=[cof,inv])

# %%
g

# %%
# g
